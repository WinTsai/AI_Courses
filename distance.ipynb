# %%
import numpy as np

def eulidist4vector(vec1,vec2):
    len1 = len(vec1)
    len2 = len(vec2)
    if len1 != len2:
        print('length of vector is not equal!')
        return -1
    else:
        print('success!')
        i = 0
        ssquare = 0
        v1array = np.array(vec1)
        v2array = np.array(vec2)
        dist = v1array - v2array
        for i in range(len1):
            ssquare = ssquare + np.square(dist[i])
        eulid = np.sqrt(ssquare)
        return eulid

    
def manhdist4vector(vec1,vec2):
    len1 = len(vec1)
    len2 = len(vec2)
    if len1 != len2:
        print('length of vector is not equal!')
        return -1
    else:
        print('success!')
        i = 0
        manh = 0
        v1array = np.array(vec1)
        v2array = np.array(vec2)
        dist = v1array - v2array
        for i in range(len1):
            manh = manh + abs(dist[i])
        return manh      

    
def chebdist4vector(vec1,vec2):
    len1 = len(vec1)
    len2 = len(vec2)
    if len1 != len2:
        print('length of vector is not equal!')
        return -1
    else:
        print('sunccess!')
        i = 0
        v1array = np.array(vec1)
        v2array = np.array(vec2)
        dist = v1array - v2array
        chev = np.linalg.norm(dist,ord=np.inf,axis=None,keepdims=False)
        return chev

    
def minkdist4vector(vec1,vec2,p):
    len1 = len(vec1)
    len2 = len(vec2)
    if len1 != len2:
        print('length of vector is not equal!')
        return -1
    else:
        i = 0
        ss = 0
        v1array = np.array(vec1)
        v2array = np.array(vec2)
        dist = v1array - v2array
        for i in range(len1):
            ss = ss + pow(abs(dist[i]),p)
        mink = pow(ss,1/p)
        return mink


def stEulid4vector(vec1,vec2):
    len1 = len(vec1)
    len2 = len(vec2)
    if len1 != len2:
        print('length of vector is not equal!')
        return -1
    else:
        print('success!')
        v1array = np.array(vec1)
        v2array = np.array(vec2)
        mu = (sum(vec1)+sum(vec2))/(len1+len2)
        s1array = v1array - mu
        s2array = v2array - mu
        larray = np.append(s1array,s2array)
        ssarray = larray**2
        sumarr = sum(ssarray)
        sd = sumarr/(len1+len2)
        darr = v1array -v2array
        stdist = np.sqrt(sum(darr**2))/sd
        return stdist

    
def hamingdist():
    
    
    
    
    
a = [1,1,3]
b = [2,15,7]
dist1 = eulidist4vector(a,b)
dist2 = manhdist4vector(a,b)
dist3 = chebdist4vector(a,b)
dist4 = minkdist4vector(a,b,2)
dist5 = stEulid4vector(a,b)
print(dist1)
print(dist2)
print(dist3)
print(dist4)
print(dist5)
# Out:
# success!
# success!
# sunccess!
# success!
# 14.594519519326424
# 19
# 14.0
# 14.594519519326424
# 0.5883568899168545
